# %%
'''
Tree look
      7
     / \
    2   1
   / \
  0   4
'''

class binary_treee:
    def __init__(self, data) -> None:
        self.data = data
        self.left_child = None
        self.right_child = None
    def postorder_inclss_function(node):
        if not node:
            return None
        if node.left_child:
            postorder(node.left_child)
        if node.right_child:
            postorder(node.right_child)
        print(node.data)


tree1=binary_treee(7)
tree1.left_child=binary_treee(2)
tree1.left_child.left_child=binary_treee(0)
tree1.left_child.right_child=binary_treee(4)
tree1.right_child=binary_treee(1)

print("this is the traveral of value making postorder function insider the class")
tree1.postorder_inclss_function()




def postorder(node):
    if not node:
        return None
    postorder(node.left_child)
    postorder(node.right_child)
    print(node.data)
print('\n this is the post order traveral making function outside the class')
postorder(tree1)


def inorder(node):
    if node:
        inorder(node.left_child)
        print(node.data)
        inorder(node.right_child)
print("\n")
print("This is the Inoder Binary Traveral Methed")
inorder(tree1)


def Preorder(node):
    if not node:
        return None
    print(node.data)
    Preorder(node.left_child)
    Preorder(node.right_child)

print("This is the preorder binary tree traverseal Methed","\n")
Preorder(tree1)

# %%
class binary_treee:
    def __init__(self, data) -> None:
        self.data = data
        self.left_child = None
        self.right_child = None


New_tree = binary_treee(20)
# leftChild=binary_treee('left1')
# rightChild=binary_treee('right1')
# New_tree.left_child=leftChild
# New_tree.right_child=rightChild
New_tree.left_child = binary_treee("1")
New_tree.right_child = binary_treee("2")
New_tree.left_child.left_child = binary_treee('3')
New_tree.left_child.right_child = binary_treee('4')

New_tree.right_child.left_child = binary_treee(5)
New_tree.right_child.right_child = binary_treee(6)

New_tree.right_child.right_child.right_child = binary_treee(9000)
New_tree.right_child.right_child.right_child.left_child = binary_treee(00)
New_tree.right_child.right_child.right_child.right_child = binary_treee(100000)

New_tree.left_child.left_child.right_child = binary_treee('lastnode')

# --.function to traverse the \tree according to Preorder


def Preorder(node):
    if not node:
        return None
    print(node.data)
    Preorder(node.left_child)
    Preorder(node.right_child)

print("This is the preorder binary tree traverseal Methed","\n")
Preorder(New_tree)

# ---function for inorder binary tree traversal


def inorder(node):
    if not node:
        return None
    inorder(node.left_child)
    print(node.data)
    inorder(node.right_child)
print("\n")
print("This is the Inoder Binary Traveral Methed")
inorder(New_tree)



def Postorder(node):
    if not node:
        return None
    Postorder(node.left_child)
    Postorder(node.right_child)
    print(node.data)
print("\n")
print("This is the Postorder Binary Traveral Methed")
Postorder(New_tree)
# Out:
# This is the preorder binary tree traverseal Methed
#
# 20
# 1
# 3
# lastnode
# 4
# 2
# 5
# 6
# 9000
# 0
# 100000
#
#
# This is the Inoder Binary Traveral Methed
# 3
# lastnode
# 1
# 4
# 20
# 5
# 2
# 6
# 0
# 9000
# 100000
#
#
# This is the Postorder Binary Traveral Methed
# lastnode
# 3
# 4
# 1
# 5
# 0
# 100000
# 9000
# 6
# 2
# 20

# %%
class TreeNode:
    def __init__(self, data):
        self.data = data
        self.leftChild = None
        self.rightChild = None


newBT = TreeNode("Drinks")
leftChild = TreeNode("Hot")
tea = TreeNode("Tea")
coffee = TreeNode("Coffee")
leftChild.leftChild = tea
leftChild.rightChild = coffee
rightChild = TreeNode("Cold")
newBT.leftChild = leftChild
newBT.rightChild = rightChild


def preOrderTraversal(rootNode):
    if not rootNode:
        return
    print(rootNode.data)
    preOrderTraversal(rootNode.leftChild)
    preOrderTraversal(rootNode.rightChild)


preOrderTraversal(newBT)
# Out:
# Drinks
# Hot
# Tea
# Coffee
# Cold

# %%
'''
Tree look
      7
     / \
    2   1
   / \
  0   4
'''

class binary_treee:
    def __init__(self, data) -> None:
        self.data = data
        self.left_child = None
        self.right_child = None
    def postorder_inclss_function(node):
        if not node:
            return None
        if node.left_child:
            postorder(node.left_child)
        if node.right_child:
            postorder(node.right_child)
        print(node.data)


tree1=binary_treee(7)
tree1.left_child=binary_treee(2)
tree1.left_child.left_child=binary_treee(0)
tree1.left_child.right_child=binary_treee(4)
tree1.right_child=binary_treee(1)

print("this is the traveral of value making postorder function insider the class")
tree1.postorder_inclss_function()




def postorder(node):
    if not node:
        return None
    postorder(node.left_child)
    postorder(node.right_child)
    print(node.data)
print('\n this is the post order traveral making function outside the class')
postorder(tree1)


def inorder(node):
    if node:
        inorder(node.left_child)
        print(node.data)
        inorder(node.right_child)
print("\n")
print("This is the Inoder Binary Traveral Methed")
inorder(tree1)


def Preorder(node):
    if not node:
        return None
    print(node.data)
    Preorder(node.left_child)
    Preorder(node.right_child)

print("This is the preorder binary tree traverseal Methed","\n")
Preorder(tree1)
# Out:
# this is the traveral of value making postorder function insider the class
# 0
# 4
# 2
# 1
# 7
#
#  this is the post order traveral making function outside the class
# 0
# 4
# 2
# 1
# 7
#
#
# This is the Inoder Binary Traveral Methed
# 0
# 2
# 4
# 7
# 1
# This is the preorder binary tree traverseal Methed
#
# 7
# 2
# 0
# 4
# 1

# %%
def levelOrderTraversal(rootNode):
    if not rootNode:
        return
    else:
        customQueue = queue.Queue()
        customQueue.enqueue(rootNode)
        while not(customQueue.isEmpty()):
            root = customQueue.dequeue()
            print(root.value.data)
            if (root.value.leftChild is not None):
                customQueue.enqueue(root.value.leftChild)
            
            if (root.value.rightChild is not None):
                customQueue.enqueue(root.value.rightChild)

# %%
# Out:
# Level order traversal of binary tree is -
# 1 2 3 4 5

# %%
# Recursive Python program for level
# order traversal of Binary Tree

# A node structure


class Node:

	# A utility function to create a new node
	def __init__(self, key):
		self.data = key
		self.left = None
		self.right = None


# Function to print level order traversal of tree
def printLevelOrder(root):
	h = height(root)
	for i in range(1, h+1):
		printCurrentLevel(root, i)


# Print nodes at a current level
def printCurrentLevel(root, level):
	if root is None:
		return
	if level == 1:
		print(root.data, end=" ")
	elif level > 1:
		printCurrentLevel(root.left, level-1)
		printCurrentLevel(root.right, level-1)


""" Compute the height of a tree--the number of nodes
	along the longest path from the root node down to
	the farthest leaf node
"""


def height(node):
	if node is None:
		return 0
	else:
		# Compute the height of each subtree
		lheight = height(node.left)
		rheight = height(node.right)

		# Use the larger one
		if lheight > rheight:
			return lheight+1
		else:
			return rheight+1


# Driver program to test above function
root = Node(1)
root.left = Node(2)
root.right = Node(3)
root.left.left = Node(4)
root.left.right = Node(5)



print("Level order traversal of binary tree is -")
printLevelOrder(root)

# This code is contributed by Nikhil Kumar Singh(nickzuck_007)
# Out:
# Level order traversal of binary tree is -
# 1 2 3 4 5

# %%
def levelorder(root):
    if not root:
        return []
    q=[root]
    next_queue=[]
    level=[]
    result=[]
    while q!=[]:
        for root in q:
            level.append(root.data)
            if root.left_child is not None:
                next_queue.append(root.left_child)
            
             
            if root.right_child is not None:
                next_queue.append(root.right_child)
        result.append(level)
        level=[]
        q=next_queue
        next_queue=[]       
    return result

print(levelorder(tree1))
# Out:
# [[7], [2, 1], [0, 4]]

# %%
'''
Tree look
      7
     / \
    2   1
   / \
  0   4
'''

class binary_treee:
    def __init__(self, data) -> None:
        self.data = data
        self.left_child = None
        self.right_child = None
    def printtree(self):
        
        if self.left_child:
            self.left_child.printtree()
        print(self.data)
        if self.right_child:
            self.right_child.printtree()
    # def postorder(node):
    #     if not node:
    #         return None
    #     node.left_child.postorder()
    #     node.right_child.postorder()
    #     # postorder(node.left_child)
    #     # postorder(node.right_child)
    #     print(node.data)
    
tree1=binary_treee(7)
tree1.left_child=binary_treee(2)
tree1.left_child.left_child=binary_treee(0)
tree1.left_child.right_child=binary_treee(4)
tree1.right_child=binary_treee(1)

# tree1.postorder()

def postorder(node):
    if not node:
        return None
    postorder(node.left_child)
    postorder(node.right_child)
    print(node.data)

postorder(tree1)


def inorder(node):
    if node:
        inorder(node.left_child)
        print(node.data)
        inorder(node.right_child)
print("\n")
print("This is the Inoder Binary Traveral Methed")
inorder(tree1)


def Preorder(node):
    if not node:
        return None
    print(node.data)
    Preorder(node.left_child)
    Preorder(node.right_child)

print("This is the preorder binary tree traverseal Methed","\n")
Preorder(tree1)

print("\n\n")
tree1.printtree()
# Out:
# 0
# 4
# 2
# 1
# 7
#
#
# This is the Inoder Binary Traveral Methed
# 0
# 2
# 4
# 7
# 1
# This is the preorder binary tree traverseal Methed
#
# 7
# 2
# 0
# 4
# 1
#
#
#
# 0
# 2
# 4
# 7
# 1

# %%
'''
SEARCHING FOR A NODE IN BINARY TREEE


'''

'''
this is function to search the node in binary treee using recurstion
time comp. is O(n)

'''




def searchNode(rootnode,value):
    if not rootnode:
        return False
    if rootnode.data==value:
        return True

    r1=searchNode(rootnode.left_child,value)
    if r1  :
        return r1
    else:
        searchNode(rootnode.right_child,value)
        
    # return r2

# print(searchNode(tree1,22))

# if searchNode(tree1,212):
#     print("found")
# else:
#     print('not found')
    
print("found" if searchNode(tree1,21) else "Not found")
# Out:
# Not found
